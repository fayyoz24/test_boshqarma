# %%
# Load JSON from file
import json
with open('test-answers.json', 'r', encoding='utf-8') as file:
    questions_data = json.load(file)

# %%
import pandas as pd
df = pd.read_excel('8-sinf.xlsx')
df['Unnamed: 1'][2]
df['Unnamed: 2'][2]
# Out:
# 'SHAMSIDDINOVA E’ZOZA JAMSHIDDIN QIZI'

# %%
family_name = df['Unnamed: 2'][2].split(" ")[0]
first_name = df['Unnamed: 2'][2].split(" ")[1]
last_name = df['Unnamed: 2'][2].split(" ")[2] + " " + df['Unnamed: 2'][2].split(" ")[3]

# %%
df['Unnamed: 1'][2].replace("-", " ")
# Out:
# '8 A'

# %%
import json

with open("english_8_a.json", 'r') as file:
    data = json.load(file)

len(data['questions'])
# Out:
# 50

# %%
# Import necessary libraries
import json
import django
import os
from django.core.wsgi import get_wsgi_application

# Setup Django environment
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'IT_KLASTER/klaster/klaster/settings.py')  # Replace with your project name
django.setup()

# Import your models
from test_olish.models import Question, Option, Theme  # Replace 'your_app' with your app name
from corecode.models import Subject, Class
# Your JSON data (you can also load this from a file)
questions_data = questions_data

def import_questions():
    subject = Subject.objects.get_or_create(name = "Ona tile")
    class_ = Class.objects.get_or_create(name = "5 A")
    # Get or create a theme
    theme, created = Theme.objects.get_or_create(name="Fonetika", 
    subject=subject, class_name=class_)  # Replace with your desired theme name
    
    # Counter for tracking progress
    questions_created = 0
    options_created = 0
    
    try:
        # Iterate through each question in the data
        for q_data in questions_data['questions']:
            # Create question
            question = Question.objects.create(
                theme=theme,
                title=q_data['question']
            )
            questions_created += 1
            
            # Create options for the question
            for opt in q_data['options']:
                for letter, content in opt.items():
                    if letter in ['A', 'B', 'C', 'D']:
                        Option.objects.create(
                            question=question,
                            title=content,
                            is_correct=opt['is_correct']
                        )
                        options_created += 1
        
        print(f"Successfully imported {questions_created} questions and {options_created} options")
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# Run the import function
if __name__ == "__main__":
    import_questions()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 9
#       7 # Setup Django environment
#       8 os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'IT_KLASTER/klaster/klaster/settings.py')  # Replace with your project name
# ----> 9 django.setup()
#      11 # Import your models
#      12 from test_olish.models import Question, Option, Theme  # Replace 'your_app' with your app name
#
# File c:\Users\GitHub\IT_claster _TEST\.venv\lib\site-packages\django\__init__.py:19, in setup(set_prefix)
#      16 from django.urls import set_script_prefix
#      17 from django.utils.log import configure_logging
# ---> 19 configure_logging(settings.LOGGING_CONFIG, settings.LOGGING)
#      20 if set_prefix:
#      21     set_script_prefix(
#      22         "/" if settings.FORCE_SCRIPT_NAME is None else settings.FORCE_SCRIPT_NAME
#      23     )
#
# File c:\Users\GitHub\IT_claster _TEST\.venv\lib\site-packages\django\conf\__init__.py:102, in LazySettings.__getattr__(self, name)
#     100 """Return the value of a setting and cache it in self.__dict__."""
#     101 if (_wrapped := self._wrapped) is empty:
# --> 102     self._setup(name)
#     103     _wrapped = self._wrapped
#     104 val = getattr(_wrapped, name)
#
# File c:\Users\GitHub\IT_claster _TEST\.venv\lib\site-packages\django\conf\__init__.py:89, in LazySettings._setup(self, name)
#      81     desc = ("setting %s" % name) if name else "settings"
#      82     raise ImproperlyConfigured(
#      83         "Requested %s, but settings are not configured. "
#      84         "You must either define the environment variable %s "
#      85         "or call settings.configure() before accessing settings."
#      86         % (desc, ENVIRONMENT_VARIABLE)
#      87     )
# ---> 89 self._wrapped = Settings(settings_module)
#
# File c:\Users\GitHub\IT_claster _TEST\.venv\lib\site-packages\django\conf\__init__.py:217, in Settings.__init__(self, settings_module)
#     214 # store the settings module in case someone later cares
#     215 self.SETTINGS_MODULE = settings_module
# --> 217 mod = importlib.import_module(self.SETTINGS_MODULE)
#     219 tuple_settings = (
#     220     "ALLOWED_HOSTS",
#     221     "INSTALLED_APPS",
#    (...)
#     224     "SECRET_KEY_FALLBACKS",
#     225 )
#     226 self._explicit_settings = set()
#
# File C:\Program Files\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'klaster'

# %%
import re
import json
from docx import Document

def clean_text(text):
    # Remove LaTeX-style formatting
    text = re.sub(r'\$.*?\$', lambda m: m.group().replace('$', ''), text)
    # Remove HTML comments
    text = re.sub(r'<!--.*?-->', '', text)
    # Remove other special formatting
    text = text.replace('{=html}', '')
    text = text.replace('\\', '')
    return text.strip()

def extract_questions(content):
    questions = []
    current_question = None
    current_options = []
    correct_answer = None
    
    lines = content.split('\n')
    for line in lines:
        line = clean_text(line)
        
        # Skip empty lines
        if not line.strip():
            continue
            
        # Check for question number
        question_match = re.match(r'^(\d+)\.(.+)', line)
        if question_match:
            # Save previous question if exists
            if current_question:
                questions.append({
                    "question": current_question,
                    "image": None,
                    "options": current_options,
                })
            
            # Start new question
            current_question = question_match.group(2).strip()
            current_options = []
            continue
            
        # Check for options
        option_match = re.match(r'^[#]?([A-D])[)\.]?\s*(.+)', line)
        if option_match:
            is_correct = line.startswith('#')
            option_letter = option_match.group(1)
            option_text = option_match.group(2).strip()
            
            current_options.append({
                option_letter: option_text,
                "image": None,
                "is_correct": is_correct
            })
    
    # Add the last question
    if current_question:
        questions.append({
            "question": current_question,
            "image": None,
            "options": current_options
        })
    
    return questions

def save_to_json(questions, filename):
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(questions, f, ensure_ascii=False, indent=2)

# Extract content from your document
def process_math_test(docx_path):
    # Read the Word document
    doc = Document(docx_path)
    
    # Extract text from the document
    full_text = []
    for paragraph in doc.paragraphs:
        full_text.append(paragraph.text)
    
    content = '\n'.join(full_text)
    
    questions = extract_questions(content)
    save_to_json(questions, 'math_test_5-6.json')
    return len(questions)

# Get the document content
try:
    num_questions = process_math_test('5-6 math.docx')
    print(f"Successfully processed {num_questions} questions")
except Exception as e:
    print(f"Error processing document: {str(e)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import re
#       2 import json
# ----> 3 from docx import Document
#       5 def clean_text(text):
#       6     # Remove LaTeX-style formatting
#       7     text = re.sub(r'\$.*?\$', lambda m: m.group().replace('$', ''), text)
#
# ModuleNotFoundError: No module named 'docx'

# %%
import pandas as pd

# Student data
data = [
    ["abdumajid", "Abdumajid", "Najimov", "5 A IT klaster Qarshi shahri"],
    ["asilbek", "Asilbek", "Yusupov", "5 A IT klaster Qarshi shahri"],
    ["nurlan", "Nurlan", "Ro'zimurodov", "5 A IT klaster Qarshi shahri"],
    ["amirbek", "Amirbek", "Asrorov", "6 A IT klaster Qarshi shahri"],
    ["nurillo", "Nurillo", "Sheraliyev", "6 A IT klaster Qarshi shahri"],
    ["saidakbar", "Saidakbar", "Sirojiddinov", "6 A IT klaster Qarshi shahri"],
    ["zafar", "Zafar", "Xamidov", "6 A IT klaster Qarshi shahri"],
    ["husayn", "Husayn", "Amirqulov", "7 A IT klaster Qarshi shahri"],
    ["javohir", "Javohir", "Ro'zmurodov", "7 A IT klaster Qarshi shahri"],
    ["shohjahon", "Shohjahon", "Ilhomov", "7 A IT klaster Qarshi shahri"],
    ["zuhriddin", "Zuhriddin", "Qulmaxmatov", "7 A IT klaster Qarshi shahri"],
    ["alisher", "Alisher", "Aliqulov", "8 A IT klaster Qarshi shahri"],
    ["asilbek913", "Asilbek", "Asrorov", "8 A IT klaster Qarshi shahri"],
    ["barhayot", "Barhayot", "Bekpulatov", "8 A IT klaster Qarshi shahri"],
    ["islom", "Islom", "Shokirov", "8 A IT klaster Qarshi shahri"],
    ["manguberd", "Manguberd", "Bo'riyev", "8 A IT klaster Qarshi shahri"],
    ["mohinur", "Mohinur", "Sirojiddinova", "8 A IT klaster Qarshi shahri"],
    ["nodir", "Nodir", "Usmonov", "8 A IT klaster Qarshi shahri"],
    ["olmos", "Olmos", "Isomiddinov", "8 A IT klaster Qarshi shahri"],
    ["abdulaziz", "Abdulaziz", "Shodiyev", "9 A IT klaster Qarshi shahri"],
    ["abror", "Abror", "Baxtiyorov", "9 A IT klaster Qarshi shahri"],
    ["humoyun", "Humoyun", "Bahromov", "9 A IT klaster Qarshi shahri"],
    ["jahongir", "Jahongir", "Ravshanov", "9 A IT klaster Qarshi shahri"],
    ["murodbek", "Murodbek", "To'ychiyev", "9 A IT klaster Qarshi shahri"],
    ["otabek", "Otabek", "Yunusov", "9 A IT klaster Qarshi shahri"],
    ["setora", "Setora", "None", "9 A IT klaster Qarshi shahri"],
    ["shahobiddin", "Shahobiddin", "Xudayqulov", "9 A IT klaster Qarshi shahri"],
    ["to'rabek", "To'rabek", "None", "9 A IT klaster Qarshi shahri"],
    ["farhod", "Farhod", "Muiddinov", "10 A IT klaster Qarshi shahri"],
    ["murodbek926", "Murodbek", "Arslonov", "10 A IT klaster Qarshi shahri"],
    ["ozodbek", "Ozodbek", "Karimov", "10 A IT klaster Qarshi shahri"],
    ["rahimjon", "Rahimjon", "To'laganov", "10 A IT klaster Qarshi shahri"],
    ["behruz", "Behruz", "Qoraboyev", "11 A IT klaster Qarshi shahri"],
    ["botir", "Botir", "Qo'chqorov", "11 A IT klaster Qarshi shahri"],
    ["ozodbek567", "Ozodbek", "Ma'murov", "11 A IT klaster Qarshi shahri"],
    ["shaxriyor", "Shaxriyor", "Baxtiyorov", "11 A IT klaster Qarshi shahri"]
]

# Create DataFrame
df = pd.DataFrame(data, columns=["Username", "First Name", "Last Name", "Current class"])

# Save to Excel file
df.to_excel("student_data.xlsx", index=False)

print("Excel file 'student_data.xlsx' has been created successfully!")
# Out:
# Excel file 'student_data.xlsx' has been created successfully!

# %%
import pandas as pd

# Combine both data parts
data_part1 = """
	alisher796	ALISHER	ALIQULOV	8 V 34 Qarshi shahri
	amina	AMINA	TOSHPULATOVA	8 V 34 Qarshi shahri
	asilabonu	ASILABONU	AKMALJONOVA	8 V 34 Qarshi shahri
	asilbek741	ASILBEK	XUDAYBERDIYEV	8 V 34 Qarshi shahri
	asilbek454	ASILBEK	ASROROV	8 V 34 Qarshi shahri
	azimjon	AZIMJON	AXROROV	8 V 34 Qarshi shahri
	barhayotbek	BARHAYOTBEK	BEKPO'LATOV	8 V 34 Qarshi shahri
	bexruzjon	BEXRUZJON	MURODULLAYEV	8 V 34 Qarshi shahri
	charos	CHAROS	URALOVA	8 V 34 Qarshi shahri
	dilshod	DILSHOD	MUSTAFAYEV	8 V 34 Qarshi shahri
	dilshoda	DILSHODA	JOMURODOVA	8 V 34 Qarshi shahri
	farruh	FARRUH	RASHIDOV	8 V 34 Qarshi shahri
	farzona585	FARZONA	AXADULLAYEVA	8 V 34 Qarshi shahri
	feruza370	FERUZA	AVAZOVA	8 V 34 Qarshi shahri
	islombek	ISLOMBEK	SHOKIROV	8 V 34 Qarshi shahri
	jasmina	JASMINA	BOBOMURODOVA	8 V 34 Qarshi shahri
	kamoliddin	KAMOLIDDIN	NURIDDINOV	8 V 34 Qarshi shahri
	komiljon	KOMILJON	MAJIDOV	8 V 34 Qarshi shahri
	komronbek	KOMRONBEK	RAXMANOV	8 V 34 Qarshi shahri
	madinabonu	MADINABONU	SAMARIDDINOVA	8 V 34 Qarshi shahri
	manguberdi986	MANGUBERDI	BO'RIYEV	8 V 34 Qarshi shahri
	moxirbek	MOXIRBEK	CHARIYEV	8 V 34 Qarshi shahri
	murodjon755	MURODJON	KOMILOV	8 V 34 Qarshi shahri
	muxlisa	MUXLISA	UMAROVA	8 V 34 Qarshi shahri
	navrozali	NAVRO'ZALI	MERZAYEV	8 V 34 Qarshi shahri
	nizomiddin	NIZOMIDDIN	HAMDAMOV	8 V 34 Qarshi shahri
	nodirbek	NODIRBEK	USMANOV	8 V 34 Qarshi shahri
	sarvar	SARVAR	AZIMOV	8 V 34 Qarshi shahri
	shamsiya	Shamsiya	Sheraliyeva	8 V 34 Qarshi shahri
	ulugbek	ULUG'BEK	MALIKOV	8 V 34 Qarshi shahri
	umida	UMIDA	SHOMURODOVA	8 V 34 Qarshi shahri
	umidjon352	UMIDJON	QAHRAMONOV	8 V 34 Qarshi shahri
	aburayxon	ABURAYXON	JUMANAZAROV	8 G 34 Qarshi shahri
	anisjon	ANISJON	XUSENOV	8 G 34 Qarshi shahri
	arslon	ARSLON	XAYDAROV	8 G 34 Qarshi shahri
	asrorbek	ASRORBEK	ULASHOV	8 G 34 Qarshi shahri
	baxtiyor52	BAXTIYOR	JOVLIYEV	8 G 34 Qarshi shahri
	dilnura608	DILNURA	SA'DINOVA	8 G 34 Qarshi shahri
	diyora	DIYORA	MUSURMONOVA	8 G 34 Qarshi shahri
	elbek	ELBEK	NORMAMATOV	8 G 34 Qarshi shahri
	fotima	FOTIMA	UROQOVA	8 G 34 Qarshi shahri
	hojiakbar	HOJIAKBAR	XUSANOV	8 G 34 Qarshi shahri
	jaloliddin	JALOLIDDIN	MARUFOV	8 G 34 Qarshi shahri
	kamola	KAMOLA	ERKINOVA	8 G 34 Qarshi shahri
	mardon	MARDON	MAMATOV	8 G 34 Qarshi shahri
	mamurjon	MA'MURJON	ALISHEROV	8 G 34 Qarshi shahri
	muslima	MUSLIMA	BABAMURODOVA	8 G 34 Qarshi shahri
	navrozbek	NAVRO'ZBEK	XURRAMOV	8 G 34 Qarshi shahri
	ozodbek247	OZODBEK	OLIMJONOV	8 G 34 Qarshi shahri
	samir	SAMIR	QULDOSHEV	8 G 34 Qarshi shahri
	shoxruz	SHOXRUZ	MELIYEV	8 G 34 Qarshi shahri
	sunnatilla	Sunnatilla	Aslonov	8 G 34 Qarshi shahri
	ural	URAL	DOVUTOV	8 G 34 Qarshi shahri
	xasan560	XASAN	USMONOV	8 G 34 Qarshi shahri
	xusen	XUSEN	USMONOV	8 G 34 Qarshi shahri
	yashin	YASHIN	NURULLAYEV	8 G 34 Qarshi shahri
	zafar54	ZAFAR	DILMURODOV	8 G 34 Qarshi shahri
	zuhra	ZUHRA	UROQOVA	8 G 34 Qarshi shahri
	zulfiqor	ZULFIQOR	BURXANOV	8 G 34 Qarshi shahri
	adham	ADHAM	ABDUG'ANIYEV	8 D 34 Qarshi shahri
	akmalshox	AKMALSHOX	BAXROMOV	8 D 34 Qarshi shahri
	alijon	ALIJON	RAXIMOV	8 D 34 Qarshi shahri
	asadbek	ASADBEK	ISABOYEV	8 D 34 Qarshi shahri
	asilbek508	ASILBEK	JUMAYEV	8 D 34 Qarshi shahri
	avazbek	AVAZBEK	NURALIYEV	8 D 34 Qarshi shahri
	azizbek	AZIZBEK	BOSHMANOV	8 D 34 Qarshi shahri
	barno	BARNO	XUSHMURODOVA	8 D 34 Qarshi shahri
	behroz	BEHRO`Z	KLICHEV	8 D 34 Qarshi shahri
	boburjon	BOBURJON	BOYNAZAROV	8 D 34 Qarshi shahri
	fayoz	FAYOZ	TOXIROV	8 D 34 Qarshi shahri
	fotima796	FOTIMA	MANSUROVA	8 D 34 Qarshi shahri
	gavharshodbegim	GAVHARSHODBEGIM	NORQULOVA	8 D 34 Qarshi shahri
	gulshoda	GULSHODA	QORJOVOVA	8 D 34 Qarshi shahri
	iroda	IRODA	XUDOYAROVA	8 D 34 Qarshi shahri
	jamshid	JAMSHID	PARDAYEV	8 D 34 Qarshi shahri
	javharbek	JAVHARBEK	KARAMATOV	8 D 34 Qarshi shahri
	javlon	JAVLON	RISKULOV	8 D 34 Qarshi shahri
	kamronbek	KAMRONBEK	JO'RAYEV	8 D 34 Qarshi shahri
	miraziz	MIRAZIZ	SAMATOV	8 D 34 Qarshi shahri
	munira	MUNIRA	BOYSORIYEVA	8 D 34 Qarshi shahri
	murodil	MURODIL	RISQULOV	8 D 34 Qarshi shahri
	muxammadali	MUXAMMADALI	CHORIYEV	8 D 34 Qarshi shahri
	muxlisa65	MUXLISA	ABDIMURATOVA	8 D 34 Qarshi shahri
	osiyo	OSIYO	XUDAYQULOVA	8 D 34 Qarshi shahri
	quvonchbek207	QUVONCHBEK	XAITMURODOV	8 D 34 Qarshi shahri
	sarvar123	SARVAR	KENJAYEV	8 D 34 Qarshi shahri
	sherali	SHERALI	RAJABOV	8 D 34 Qarshi shahri
	sugdiyona	SUG'DIYONA	O'KTAMOVA	8 D 34 Qarshi shahri
	suxrob	SUXROB	QAHHOROV	8 D 34 Qarshi shahri
	umida353	UMIDA	QIYOMOVA	8 D 34 Qarshi shahri
	zuxra	ZUXRA	MANSUROVA	8 D 34 Qarshi shahri
"""

data_part2 = """
shahriabdumalikABDUMALIKBEKMURADOV8 A 34 Qarshi shahriafrozAFRO'ZUMAROV8 A 34 Qarshi shahriangelinaANGELINARAXMEDOVA8 A 34 Qarshi shahriasalASALASADULLAYEVA8 A 34 Qarshi shahriasilbek149ASILBEKZARIBOV8 A 34 Qarshi shahribehruzbekBEHRUZBEKTURSINOV8 A 34 Qarshi shahridilnuraDILNURASHOVKATOVA8 A 34 Qarshi shahriezozaE'ZOZASHAMSIDDINOVA8 A 34 Qarshi shahrifarangizFARANGIZBERDIYEVA8 A 34 Qarshi shahrifarzonaFARZONAPARDAYEVA8 A 34 Qarshi shahrifirdavs909FIRDAVSUMIROV8 A 34 Qarshi shahrifirdavsFIRDAVSPINNAZAROV8 A 34 Qarshi shahrifirdavsbekFIRDAVSBEKABDIALIMOV8 A 34 Qarshi shahrigulinurGULINURAXMEDOV8 A 34 Qarshi shahriismoilISMOILSIROJIDDINOV8 A 34 Qarshi shahrikumushKUMUSHTILLAYEVA8 A 34 Qarshi 
shahrimohinur513MOHINURSIROJIDDINOVA8 A 34 Qarshi shahrinozliNOZLIXAMITOVA8 A 34 Qarshi shahrinurididaNURIDIDAXOLMAXMATOVA8 A 34 Qarshi shahriotabek594OtabekMalikov8 A 34 Qarshi shahriparizoda935PARIZODAKAXRAMONOVA8 A 34 Qarshi shahriparizodaPARIZODAKOMILOVA8 A 34 Qarshi shahrisamandarSAMANDARABDINAZAROV8 A 34 Qarshi shahrisamiraSAMIRAMIRZAYEVA8 A 34 Qarshi shahrisayyoraSAYYORAXOLIYOROVA8 A 34 Qarshi shahritemurbekTEMURBEKYAKUBOV8 A 34 Qarshi shahriumidjonUMIDJONUMIROV8 A 34 Qarshi shahrixadijabegimXADIJABEGIMQAYUMOVA8 A 34 Qarshi shahrixojiakbarXOJIAKBARABDIRAYIMOV8 A 34 Qarshi shahriakobirAKOBIRNORTOJIYEV8 B 34 Qarshi shahrialisher254ALISHERESHDAVLATOV8 B 34 Qarshi shahriasliddinASLIDDINMURTAZAYEV8 B 34 Qarshi shahribaxoraBAXORAGIYOSIDDINOVA8 B 34 Qarshi shahribaxtiyorBAXTIYORABDUMURODOV8 B 34 Qarshi shahridurdonaxonDURDONAXONMIZROBOVA8 B 34 Qarshi shahrifarangiz0FARANGIZBAYKOBILOVA8 B 34 Qarshi shahrifirdavs550FirdavsNurmamatov8 B 34 Qarshi shahrihasanHASANXOLMURODOV8 B 34 Qarshi shahrihusanHUSANXOLMURODOV8 B 34 Qarshi shahriikromjonIKROMJONKUCHIMOV8 B 34 Qarshi shahrijavoxirJAVOXIRFARMONOV8 B 34 Qarshi shahrilazizbekLAZIZBEKDAVRONOV8 B 34 Qarshi shahrilutfiyaLUTFIYAXOLIQULOVA8 B 34 Qarshi shahrimadinaMADINASAIDOVA8 B 34 Qarshi shahrimirjalolMIRJALOLBO'RIBOYEV8 B 34 Qarshi shahrimurodjonMURODJONNIZOMOV8 B 34 Qarshi shahrinamozNAMOZKARIMOV8 B 34 Qarshi shahriqilichbekQILICHBEKXUDOYNAZAROV8 B 34 Qarshi shahriquvonchbekQUVONCHBEKRAXMONKULOV8 B 34 Qarshi shahriravshanRAVSHANKAMOLOV8 B 34 Qarshi shahrisarvarbekSARVARBEKTEMIROV8 B 34 Qarshi shahrisunnatbekSunnatbekUrokov8 B 34 Qarshi shahritemurbek507TEMURBEKXUDOYNAZAROV8 B 34 Qarshi shahriumarbekUMARBEKXALILOV8 B 34 Qarshi shahrixasanXASANNUSRATULLAYEV8 B 34 Qarshi shahrixusanXUSANNUSRATULLAYEV8 B 34 Qarshi shahrizaxroZAXROFARMONOVA8 B 34 Qarshi shahrizebuzarZEBUZARRAVSHANOVA8 B 34 Qarshi shahriakromjonAKROMJONQURG'ONBOYEV8 V 34 Qarshi shahri
"""

# Parse part 1 data
rows = []
for line in data_part1.strip().split('\n'):
    parts = line.strip().split('\t')
    if len(parts) >= 4:
        username = parts[0].strip()
        first_name = parts[1].strip()
        last_name = parts[2].strip()
        current_class = parts[3].strip()
        rows.append([username, first_name, last_name, current_class])

# Parse part 2 data which has a different format
import re
part2_data = data_part2.strip().replace('\n', '')
# Match pattern: username followed by first name, last name, and class
pattern = r'shahri([a-z0-9]+)([A-Z][A-Za-z\'`]+)([A-Z][A-Za-z\'`]+)(8 [A-Z] 34 Qarshi shahri)'
matches = re.findall(pattern, part2_data)

for match in matches:
    username = match[0]
    first_name = match[1]
    last_name = match[2]
    current_class = match[3]
    rows.append([username, first_name, last_name, current_class])

# Create DataFrame
df = pd.DataFrame(rows, columns=['Username', 'First Name', 'Last Name', 'Current Class'])

# Convert to Excel
df.to_excel('student_data-8-34.xlsx', index=False)
print("Excel file created with", len(df), "student records")
# Out:
# Excel file created with 121 student records

# %%
import docx
import re
import json
import argparse
from typing import List, Dict, Any, Optional, Tuple

def extract_problems(document_path: str) -> List[Dict[str, Any]]:
    """
    Extract math problems from a Word document and convert to JSON with LaTeX notation.
    
    Args:
        document_path: Path to the .docx file
        
    Returns:
        List of problem dictionaries ready for JSON serialization
    """
    # Load the document
    doc = docx.Document(document_path)
    
    problems = []
    current_problem = None
    current_options = []
    correct_option = None
    
    # Regular expressions for parsing
    problem_pattern = re.compile(r'^\s*(\d+)\.\s*(.+)$')
    option_pattern = re.compile(r'^\s*([A-D])\)\s*(.+?)\s*(#)?$')
    
    for paragraph in doc.paragraphs:
        text = paragraph.text.strip()
        if not text:
            continue
        
        # Check if this is a new problem
        problem_match = problem_pattern.match(text)
        if problem_match:
            # Save previous problem if exists
            if current_problem and current_options:
                problems.append(create_problem_dict(current_problem, current_options, correct_option))
                current_options = []
                correct_option = None
            
            # Start new problem
            _, problem_text = problem_match.groups()
            current_problem = problem_text
        else:
            # Check if this is an option
            option_match = option_pattern.match(text)
            if option_match and current_problem:
                option_letter, option_text, is_correct = option_match.groups()
                current_options.append((option_letter, option_text))
                if is_correct:
                    correct_option = option_letter
    
    # Add the last problem
    if current_problem and current_options:
        problems.append(create_problem_dict(current_problem, current_options, correct_option))
    
    return problems

def create_problem_dict(problem_text: str, options: List[Tuple[str, str]], correct_option: Optional[str]) -> Dict[str, Any]:
    """
    Create a dictionary for a single problem with LaTeX notation.
    
    Args:
        problem_text: The text of the problem
        options: List of (letter, text) tuples for each option
        correct_option: The letter of the correct option
        
    Returns:
        Dictionary representation of the problem
    """
    # Convert to LaTeX notation
    problem_latex = convert_to_latex(problem_text)
    
    # Create options list
    options_list = []
    for letter, text in options:
        option_latex = convert_to_latex(text)
        options_list.append({
            letter: option_latex,
            "image": None,
            "is_correct": letter == correct_option
        })
    
    return {
        "question": problem_latex,
        "image": None,
        "options": options_list
    }

def convert_to_latex(text: str) -> str:
    """
    Convert mathematical expressions to LaTeX notation.
    
    Args:
        text: Text with potential mathematical expressions
        
    Returns:
        Text with LaTeX notation for mathematical expressions
    """
    # Replace common mathematical patterns with LaTeX
    # Fractions like a/b
    text = re.sub(r'(\d+)/(\d+)', r'\\frac{\1}{\2}', text)
    
    # Superscripts like x^2
    text = re.sub(r'(\w+)\^(\d+)', r'\1^{\2}', text)
    
    # Basic math operations
    text = re.sub(r'(\d+)\s*×\s*(\w+)', r'\1 \\times \2', text)
    text = re.sub(r'(\d+)\s*:\s*(\d+)', r'\1 : \2', text)
    
    # Check if the text contains mathematical expressions
    # If it contains operation symbols or other indicators, wrap in $
    math_indicators = ['\\frac', '\\times', ':', '=', '<', '>', '+', '-', '/', '\\cdot', '^']
    needs_math_delimiters = any(indicator in text for indicator in math_indicators)
    
    if needs_math_delimiters:
        # Make sure we're not double-wrapping already LaTeX-formatted text
        if not (text.startswith('$') and text.endswith('$')):
            text = f'${text}$'
    
    return text

def main():
    # Hardcoded input filename
    input_file = "Ekub va Ekuk.docx"
    
    # Generate output filename by replacing the extension with .json
    output_file = input_file.rsplit('.', 1)[0] + '.json'
    
    try:
        problems = extract_problems(input_file)
        
        # Write to JSON file
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(problems, f, ensure_ascii=False, indent=2)
        
        print(f"Successfully converted {len(problems)} problems to {output_file}")
    
    except Exception as e:
        print(f"Error: {e}")

main()
# Out:
# Successfully converted 5 problems to Ekub va Ekuk.json

# %%
import json

def read_latex_json(file_path):
    """
    Read a JSON file containing LaTeX notation.
    
    Args:
        file_path: Path to the JSON file
        
    Returns:
        The parsed JSON data
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        return data
    except Exception as e:
        print(f"Error reading JSON file: {e}")
        return None

# Example usage
file_path = "9-10-11 test.json"  # Your JSON file path
problems = read_latex_json(file_path)

if problems:
    # Process the LaTeX content
    for i, problem in enumerate(problems):
        print(f"Problem {i+1}:")
        print(f"Question: {problem['question']}")
        print("Options:")
        for option in problem['options']:
            for letter, text in option.items():
                if letter != 'image' and letter != 'is_correct':
                    correct = "✓" if option['is_correct'] else " "
                    print(f"  {letter}) {text} {correct}")
        print()
# Out:
# Problem 1:
# Question: 111213…7980 sonning raqamlaлоri yig’indisini toping.
# Options:
#   A) 602
#   B) 405
#   C) 648
#   D) 600
#
# Problem 2:
# Question: 3, 6, 7, 5 raqamlaridan tuzilgan to’rt xonali sonlarning nеchtasi 4 ga bo’linadi?
# Options:
#   A) 4
#   B) 5
#   C) 6
#   D) 7
#
# Problem 3:
# Question: Sonni beshga bo’lganda 4 qoldiq qoladi. Shu sonning kubini 5 ga bo’lganda necha qoldiq qoladi.
# Options:
#   A) 6
#   B) 4
#   C) 3
#   D) 2
#
# Problem 4:
# Question: 72 va 96 sonlarining EKUKini EKUBiga nisbatini toping.
# Options:
#   A) 10
#   B) 9
#   C) 12
#   D) 0,5
#
# Problem 5:
# Question: $100476000006+256789256789 yig’indining oxirgi raqamini toping.$
# Options:
#   A) 6
#   B) 7
#   C) 8
#   D) 9
#
# Problem 6:
# Question: $7-10+15-18+23-26+…+95-98=?$
# Options:
#   A) $-56$
#   B) $-36$
#   C) $-45$
#   A) 0,02
#   B) 4
#   C) 0,01
#   D) $\frac{2}{300}$
#
# Problem 7:
# Question: bo’lsa,
# Options:
#   A) $b-3$
#   B) $4-b$
#   C) $3-b$
#   D) $3+b$
#
# Problem 8:
# Question: 0,0015·0,016 ko’paytma quyidagilardan qaysi biriga teng emas?
# Options:
#   A) $2,4·10-5$
#   B) $240·10-7$
#   C) $24·10-6$
#   D) $0,0024·10-3$
#   A) 2
#   B) 1
#   C) $\frac{2}{3}$
#   D) $\frac{1}{3}$
#
# Problem 9:
# Question: Quyidagi sonlardan qaysilarini chekli o’nli kasr ko’rinishiga keltirib bo’lmaydi?
# Options:
#   A) 1;2
#   B) 3;4
#   C) 1;3
#   D) 2;4
#   A) $2ac-2bc$
#   B) $-2abc$
#   C) $-2bc$
#   D) $ab-ac$
#
# Problem 10:
# Question: $a+a–1=3 bo’lsa, (a6+1)/(9a3)=?$
# Options:
#   A) 18
#   B) 6
#   C) 2
#   D) 1
#
# Problem 11:
# Question: $(3x+1)(3x-1)+4y(4y-6x)+8 ifodaning eng kichik qiymatini toping.$
# Options:
#   A) 2
#   B) 3
#   C) 7
#   D) 8
#
# Problem 12:
# Question: $a4+4b4 ni ratsional ko’paytuvchilarga ajrating.$
# Options:
#   A) $(a2-2b2)(a2+2b2)$
#   B) $(a2-2ab+2b2)(a2+2ab+2b2)$
#   C) $(a2-b2)(a2+4b2)$
#   D) $(a2+2ab+2b2)(a2-2ab-2b2)$
#
# Problem 13:
# Question: ifoda n ning nechta natural quymatida natural son bo’ladi?
# Options:
#   A) 3
#   B) 1
#   C) 5
#   D) 2
#
# Problem 14:
# Question: $a+b+c=0 bo’lsa, a3+a2c-abc+b2c+b3=?$
# Options:
#   A) 0
#   B) 1
#   C) 2
#   D) $-1$
#   A) 2
#   B) 4
#   C) 0
#   D) 5
#
# Problem 15:
# Question: $bo’lsa,  2a2-5ab+2b2=?$
# Options:
#   A) 47
#   B) 2
#   C) 3
#   D) 49
#
# Problem 16:
# Question: kasr maxrajidagi irratsionallikni yo’qoting.
# Options:
#   C) 0
#
# Problem 17:
# Question: bo’lsa,
# Options:
#   A) B)     C)    D) 0
#
# Problem 18:
# Question: y mрinutda x mm yomg’ir yog’adi. 3,5 soatda necha mm yomg’ir yog’adi?
# Options:
#   A) $150x/y$
#   B) $180y/x$
#   C) $210y/x$
#   D) $210x/y$
#
# Problem 19:
# Question: $8(32+1)(34+1)(38+1)…(3512+1)x=31024-1 tenglamani yeching.$
# Options:
#   A) 8
#   B) $\frac{1}{8}$
#   C) 1
#   D) $-1$
#
# Problem 20:
# Question: Ildizlaridan biri  bo’lgan ratsional koeffitsiyentli kvadrat tenglama tuzing.
# Options:
#   A) $x2+6x+4=0$
#   B) $x2-6x+7=0$
#   C) $x2-6x+5=0$
#   D) $x2-6x-5=0$
#   A) 3
#   D) 6
#
# Problem 21:
# Question: hisoblang.
# Options:
#   A) 10
#   B) 100
#   C) 25
#   D) 142
#
# Problem 22:
# Question: ifodaning qiymati qanday raqam bilan tugaydi?
# Options:
#   A) 3
#   B) 2
#   C) 0
#   D) 8
#
# Problem 23:
# Question: Yig’indining oxirgiraqamini toping.
# Options:
#   A) 3
#   B) 5
#   C) 7
#   D) 9
#
# Problem 24:
# Question: Sistemaning natural yechimlari nechta ?
# Options:
#   A) 1
#   B) 2
#   C) 3
#   D) 4
#
# Problem 25:
# Question: Tengsizliklar sistemasining butun yechimlari yig’indisini  toping.
# Options:
#   A) 12
#   B) 8
#   C) 9
#   D) 7
#
# Problem 26:
# Question: $Agar   bo’lsa, a+b  ni toping.$
# Options:
#   A) $1  B)2  C)-1  D)-2  E)-3$
#
# Problem 27:
# Question: ni soddalashtiring.
# Options:
#   A) 1
#   B) $-1$
#   C) 2
#   D) $-2$
#
# Problem 28:
# Question: Ifodanisoddalashtiring .
# Options:
#   D) E)

# %%
import re
import json
from pathlib import Path

def convert_math_test_to_json(content):
    """
    Convert a math test document to JSON format with proper LaTeX handling.
    """
    # Split the content by questions (starting with number followed by period)
    questions_raw = re.split(r'\n\s*\*\*(\d+)\.\*\*\s*', content)
    
    # First element is header text, remove it
    header = questions_raw[0].strip()
    # The rest alternates between question numbers and question content
    question_data = []
    
    for i in range(1, len(questions_raw), 2):
        if i+1 >= len(questions_raw):
            break
            
        question_number = questions_raw[i]
        question_content = questions_raw[i+1].strip()
        
        # Extract question text and options
        options_match = re.split(r'\n\s*([A-E]\))\s*', question_content)
        
        question_text = options_match[0].strip()
        options = {}
        
        # Process options
        for j in range(1, len(options_match), 2):
            if j+1 >= len(options_match):
                break
                
            option_letter = options_match[j].replace(')', '')
            option_text = options_match[j+1].strip()
            
            # Convert image references to LaTeX placeholders
            if "![](media/image" in option_text:
                option_text = "[Image representation not available]"
            
            # Convert fractions and mathematical expressions to LaTeX
            option_text = convert_to_latex(option_text)
            options[option_letter] = option_text
        
        # Convert question text to LaTeX
        question_text = convert_to_latex(question_text)
        
        # Remove image references from question text
        if "![](media/image" in question_text:
            question_text = re.sub(r'!\[\]\(media/image\d+\.wmf\)', "[Mathematical expression]", question_text)
        
        question_data.append({
            "number": int(question_number),
            "text": question_text,
            "options": options
        })
    
    # Create the final JSON structure
    test_json = {
        "title": "Mathematics Test",
        "questions": question_data
    }
    
    return test_json

def convert_to_latex(text):
    """
    Convert mathematical expressions to LaTeX format.
    """
    # Already in LaTeX format (within $ signs)
    if '$' in text:
        return text
    
    # Convert fraction notation
    text = re.sub(r'(\d+)/(\d+)', r'\\frac{\1}{\2}', text)
    
    # Convert exponents
    text = re.sub(r'(\w+)\^(\w+)\^', r'\1^{\2}', text)
    
    # Convert square roots
    text = re.sub(r'\\sqrt{([^}]+)}', r'\\sqrt{\1}', text)
    
    # Convert bullet points to LaTeX
    text = text.replace('•', '\\bullet')
    
    return text

def save_to_json(data, output_file):
    """
    Save data to a JSON file with proper formatting.
    """
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    
    return f"Saved successfully to {output_file}"

# Example usage with the document content from your input


from docx import Document

def extract_text_from_docx(docx_path):
    doc = Document(docx_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

# Then use:


if __name__ == "__main__":
    # Use the document content directly instead of reading from a file
    document_content = extract_text_from_docx('Ekub va Ekuk.docx')

    output_file = "Ekub va Ekuk.json"
    
    # Convert to JSON
    test_json = convert_math_test_to_json(document_content)
    
    # Save to file
    result = save_to_json(test_json, output_file)
    
    print(result)
    
    # Preview the first two questions
    print("\nSample of converted content:")
    for question in test_json["questions"][:2]:
        print(f"\nQuestion {question['number']}: {question['text']}")
        for option, text in question["options"].items():
            print(f"  {option}) {text}")
# Out:
# Saved successfully to Ekub va Ekuk.json
#
# Sample of converted content:

# %%
def save_to_json(data, output_file):
    """
    Save data to a JSON file with proper formatting.
    """
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    
    return f"Saved successfully to {output_file}"

# Example usage with the document content from your input

from docx import Document

def extract_text_from_docx(docx_path):
    doc = Document(docx_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

# Then use:
document_content = extract_text_from_docx('9-10-11 test.docx')

# %%
import re
import json

def convert_to_latex_notation(text):
    """
    Convert mathematical notation to LaTeX format.
    
    :param text: Input text with mathematical expressions
    :return: Text with LaTeX notation
    """
    # Trim whitespace
    text = text.strip()
    
    # Handle exponents
    text = re.sub(r'(\w)\^(\d+)', r'\1^{\2}', text)
    
    # Handle multiplication dot
    text = text.replace('•', r'\cdot')
    
    # Add $ delimiters for math mode if not already present
    if not (text.startswith('$') and text.endswith('$')):
        text = f'${text}$'
    
    return text

def parse_problems(document_content):
    """
    Parse problems from the document content.
    
    :param document_content: Full text of the document
    :return: List of parsed problems
    """
    # Split document into lines and remove empty lines
    lines = [line.strip() for line in document_content.split('\n') if line.strip()]
    
    # Remove title
    lines = lines[1:]
    
    problems = []
    
    i = 0
    while i < len(lines):
        # Find problem line (starts with [number])
        problem_match = re.match(r'\[(\d+)\]\.(.+)', lines[i])
        if problem_match:
            # Extract problem text and remove order number
            problem_text = re.sub(r'^\s*\[(\d+)\]\.\s*', '', lines[i]).strip()
            
            # Collect options
            options = []
            for j in range(i+1, i+5):
                if j < len(lines):
                    option_match = re.match(r'([A-D])[)#]?\s*(.+)', lines[j])
                    if option_match:
                        choice_letter = option_match.group(1)
                        choice_text = option_match.group(2).strip()
                        is_correct = '#' in lines[j]
                        
                        options.append({
                            choice_letter: convert_to_latex_notation(choice_text),
                            "image": None,
                            "is_correct": is_correct
                        })
            
            # Create problem dictionary
            problem = {
                "question": convert_to_latex_notation(problem_text),
                "image": None,
                "options": options
            }
            
            problems.append(problem)
            
            # Move to next problem
            i += 5
        else:
            i += 1
    
    return problems

def main():
    # The document content is passed directly
    document_content = """**EKUB va EKUK**

**[1.]{.underline}**40 va 60 sonlarining EKUBini aniqlang\
A) 10

#B) 20

C\) 30

D\) 40

**[2.]{.underline}**$A = a^{2} \bullet b^{3} \bullet c$ va
$B = a \bullet b^{2} \bullet d$ sonlari uchun EKUB(A;B) ning qiymatini
toping.

A\) $ab$

B\) $a^{2}b$

#C) $ab^{2}$

D\) $a$

**[3.]{.underline}** EKUB(42;48)-?

A\) 2

B\) 3

#C) 6

D\) 8

**[4.]{.underline}** EKUB(24;36;48)-?\
A) 6

B\) 8

C\) 9

#D) 12

**[5.]{.underline}**$A = a^{3} \bullet b^{2} \bullet c^{5}$ va
$B = a^{2} \bullet b^{4} \bullet d^{3}$ sonlar uchun $EKUB(A;B)$ ning
qiymatini toping.

A\) $ab$

B\) $a^{2}b$

#C) $a^{2}b^{2}$

D\) $a$

**[6.]{.underline}** 32 va 48 sonlarining EKUKibi toping\
#A) 96

B\) 100

C\) 84

D\) 54

**[7.]{.underline}** EKUK(15;24) ning qiymatini toping\
A) 60

B\) 90

#C) 120

D\) 150

**[8.]{.underline}** EKUK(8;9;12) ning qiymatini toping\
A) 18

B\) 24

C\) 36

#D) 72

**[9.]{.underline}** EKUB(A;B)=10 bo\`lib A:B=3:5 bo\`lsa, A+B ning
qiymatini toping\
A) 50

B\) 70

#C) 80

D\) 90

**[10.]{.underline}** 4800 ning tub bo\`luvchilari sonini toping\
#A) 42

B\) 30

C\) 15

D\) 3

**[11.]{.underline}** 1440 ning tub bo\`luvchilari yig\`indisini toping\
A) 36

B\) 30

C\) 17

#D) 10

**[12.]{.underline}** EKUB(72;60)+EKUK(28;20) ning qiymatini toping.

A\) 119

B\) 126

C\) 136

#D) 152

**[13.]{.underline}**$A = 2^{3} \bullet 3 \bullet 5$ va
$B = 2^{2} \bullet 3^{2} \bullet 7$ sonlari uchun
$\frac{EKUK(A;B)}{EKUB(A;B)}$ ning qiymatini toping.

#A) $210$

B\) $220$

C\) $240$

D\) $280$

**[14.]{.underline}** EKUB(12;140;36)+EKUK(6;16;20) ning qiymatini
toping\
A) 198

B\) 210

#C) 244

D\) 250

**[15.]{.underline}** EKUB(18;60;x)=6 va EKUK(18;60;x)=1260 bo\`lsa, x
ning eng kichik qiymatini toping\
A) 6

B\) 18

C\) 36

#D) 42

**[16.]{.underline}** EKUB(24;x)=12 va EKUK(24;x)=120 bo\`lsa, x ning
raqamlari yig\`indisini toping\
A) 4

#B) 5

C\) 6

D\) 7

**[17.]{.underline}** EKUB(EKUK(72;20);EKUK(24;32)) ning\
qiymatini toping\
A) 18

#B) 24

C\) 36

D\) 72

**[18.]{.underline}** EKUB(x;12)∙EKUK(x;12)=720 bo\`lsa,EKUK(x;45) ning
qiymatini toping\
A) 60

B\) 90

#C) 180

D\) 240

**[19.]{.underline}** EKUB(72;25)+EKUK(14;35;30) ning qiymatini toping\
A) 121

B\) 181

C\) 205

#D) 211

**[20.]{.underline}**EKUB(54;A)=18 va EKUK(54;A)=216 bo\`lsa, A ning
qiymatini toping\
A) 36

B\) 48

C\) 54

#D) 72

**[21.]{.underline}** O\`zaro tub sonlarning EKUKi 60 ga teng bo\`lib
ulardan biri 5 ga teng bo\`lsa, ikkinchi sonni toping.

A\) 13

#B) 12

C\) 15

D\) 20

**[22.]{.underline}** EKUK(36;A)=72 va EKUB(36;A)=12 bo\`lsa, A ning
qiymatini toping\
A) 14

B\) 34

#C) 24

D)30"""
    
    # Parse problems
    problems = parse_problems(document_content)
    
    # Export to JSON file
    with open('problems.json', 'w', encoding='utf-8') as f:
        json.dump(problems, f, ensure_ascii=False, indent=2)
    
    print(f"Exported {len(problems)} problems to problems.json")

if __name__ == '__main__':
    main()
# Out:
# Exported 0 problems to problems.json

# %%
{
  "questions": [
    {
      "question": "40 va 60 sonlarining EKUBini aniqlang",
      "image": null,
      "options": [
        {
          "A": "10",
          "image": null,
          "is_correct": false
        },
        {
          "B": "20",
          "image": null,
          "is_correct": true
        },
        {
          "C": "30",
          "image": null,
          "is_correct": false
        },
        {
          "D": "40",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$A = a^{2} \\bullet b^{3} \\bullet c$ va $B = a \\bullet b^{2} \\bullet d$ sonlari uchun $EKUB(A;B)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "$ab$",
          "image": null,
          "is_correct": false
        },
        {
          "B": "$a^{2}b$",
          "image": null,
          "is_correct": false
        },
        {
          "C": "$ab^{2}$",
          "image": null,
          "is_correct": true
        },
        {
          "D": "$a$",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(42;48)$",
      "image": null,
      "options": [
        {
          "A": "2",
          "image": null,
          "is_correct": false
        },
        {
          "B": "3",
          "image": null,
          "is_correct": false
        },
        {
          "C": "6",
          "image": null,
          "is_correct": true
        },
        {
          "D": "8",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(24;36;48)$",
      "image": null,
      "options": [
        {
          "A": "6",
          "image": null,
          "is_correct": false
        },
        {
          "B": "8",
          "image": null,
          "is_correct": false
        },
        {
          "C": "9",
          "image": null,
          "is_correct": false
        },
        {
          "D": "12",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$A = a^{3} \\bullet b^{2} \\bullet c^{5}$ va $B = a^{2} \\bullet b^{4} \\bullet d^{3}$ sonlar uchun $EKUB(A;B)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "$ab$",
          "image": null,
          "is_correct": false
        },
        {
          "B": "$a^{2}b$",
          "image": null,
          "is_correct": false
        },
        {
          "C": "$a^{2}b^{2}$",
          "image": null,
          "is_correct": true
        },
        {
          "D": "$a$",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "32 va 48 sonlarining EKUKibi toping",
      "image": null,
      "options": [
        {
          "A": "96",
          "image": null,
          "is_correct": false
        },
        {
          "B": "100",
          "image": null,
          "is_correct": false
        },
        {
          "C": "84",
          "image": null,
          "is_correct": false
        },
        {
          "D": "96",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$EKUK(15;24)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "60",
          "image": null,
          "is_correct": false
        },
        {
          "B": "90",
          "image": null,
          "is_correct": false
        },
        {
          "C": "120",
          "image": null,
          "is_correct": true
        },
        {
          "D": "150",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUK(8;9;12)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "18",
          "image": null,
          "is_correct": false
        },
        {
          "B": "24",
          "image": null,
          "is_correct": false
        },
        {
          "C": "36",
          "image": null,
          "is_correct": false
        },
        {
          "D": "72",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$EKUB(A;B)=10$ bo'lib $A:B=3:5$ bo'lsa, $A+B$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "50",
          "image": null,
          "is_correct": false
        },
        {
          "B": "70",
          "image": null,
          "is_correct": false
        },
        {
          "C": "80",
          "image": null,
          "is_correct": true
        },
        {
          "D": "90",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "4800 ning tub bo'luvchilari sonini toping",
      "image": null,
      "options": [
        {
          "A": "42",
          "image": null,
          "is_correct": true
        },
        {
          "B": "30",
          "image": null,
          "is_correct": false
        },
        {
          "C": "15",
          "image": null,
          "is_correct": false
        },
        {
          "D": "3",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "1440 ning tub bo'luvchilari yig'indisini toping",
      "image": null,
      "options": [
        {
          "A": "36",
          "image": null,
          "is_correct": false
        },
        {
          "B": "30",
          "image": null,
          "is_correct": false
        },
        {
          "C": "17",
          "image": null,
          "is_correct": false
        },
        {
          "D": "10",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$EKUB(72;60)+EKUK(28;20)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "119",
          "image": null,
          "is_correct": false
        },
        {
          "B": "126",
          "image": null,
          "is_correct": false
        },
        {
          "C": "136",
          "image": null,
          "is_correct": false
        },
        {
          "D": "152",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$A = 2^{3} \\bullet 3 \\bullet 5$ va $B = 2^{2} \\bullet 3^{2} \\bullet 7$ sonlari uchun $\\frac{EKUK(A;B)}{EKUB(A;B)}$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "$210$",
          "image": null,
          "is_correct": true
        },
        {
          "B": "$220$",
          "image": null,
          "is_correct": false
        },
        {
          "C": "$240$",
          "image": null,
          "is_correct": false
        },
        {
          "D": "$280$",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(12;140;36)+EKUK(6;16;20)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "198",
          "image": null,
          "is_correct": false
        },
        {
          "B": "210",
          "image": null,
          "is_correct": false
        },
        {
          "C": "244",
          "image": null,
          "is_correct": true
        },
        {
          "D": "250",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(18;60;x)=6$ va $EKUK(18;60;x)=1260$ bo'lsa, $x$ ning eng kichik qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "6",
          "image": null,
          "is_correct": false
        },
        {
          "B": "18",
          "image": null,
          "is_correct": false
        },
        {
          "C": "36",
          "image": null,
          "is_correct": false
        },
        {
          "D": "42",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$EKUB(24;x)=12$ va $EKUK(24;x)=120$ bo'lsa, $x$ ning raqamlari yig'indisini toping",
      "image": null,
      "options": [
        {
          "A": "4",
          "image": null,
          "is_correct": false
        },
        {
          "B": "5",
          "image": null,
          "is_correct": true
        },
        {
          "C": "6",
          "image": null,
          "is_correct": false
        },
        {
          "D": "7",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(EKUK(72;20);EKUK(24;32))$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "18",
          "image": null,
          "is_correct": false
        },
        {
          "B": "24",
          "image": null,
          "is_correct": true
        },
        {
          "C": "36",
          "image": null,
          "is_correct": false
        },
        {
          "D": "72",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(x;12) \\cdot EKUK(x;12)=720$ bo'lsa, $EKUK(x;45)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "60",
          "image": null,
          "is_correct": false
        },
        {
          "B": "90",
          "image": null,
          "is_correct": false
        },
        {
          "C": "180",
          "image": null,
          "is_correct": true
        },
        {
          "D": "240",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUB(72;25)+EKUK(14;35;30)$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "121",
          "image": null,
          "is_correct": false
        },
        {
          "B": "181",
          "image": null,
          "is_correct": false
        },
        {
          "C": "205",
          "image": null,
          "is_correct": false
        },
        {
          "D": "211",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "$EKUB(54;A)=18$ va $EKUK(54;A)=216$ bo'lsa, $A$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "36",
          "image": null,
          "is_correct": false
        },
        {
          "B": "48",
          "image": null,
          "is_correct": false
        },
        {
          "C": "54",
          "image": null,
          "is_correct": false
        },
        {
          "D": "72",
          "image": null,
          "is_correct": true
        }
      ]
    },
    {
      "question": "O'zaro tub sonlarning EKUKi 60 ga teng bo'lib ulardan biri 5 ga teng bo'lsa, ikkinchi sonni toping",
      "image": null,
      "options": [
        {
          "A": "13",
          "image": null,
          "is_correct": false
        },
        {
          "B": "12",
          "image": null,
          "is_correct": true
        },
        {
          "C": "15",
          "image": null,
          "is_correct": false
        },
        {
          "D": "20",
          "image": null,
          "is_correct": false
        }
      ]
    },
    {
      "question": "$EKUK(36;A)=72$ va $EKUB(36;A)=12$ bo'lsa, $A$ ning qiymatini toping",
      "image": null,
      "options": [
        {
          "A": "14",
          "image": null,
          "is_correct": false
        },
        {
          "B": "34",
          "image": null,
          "is_correct": false
        },
        {
          "C": "24",
          "image": null,
          "is_correct": true
        },
        {
          "D": "30",
          "image": null,
          "is_correct": false
        }
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 {
#       2   "questions": [
#       3     {
#       4       "question": "40 va 60 sonlarining EKUBini aniqlang",
# ----> 5       "image": null,
#       6       "options": [
#       7         {
#       8           "A": "10",
#       9           "image": null,
#      10           "is_correct": false
#      11         },
#      12         {
#      13           "B": "20",
#      14           "image": null,
#      15           "is_correct": true
#      16         },
#      17         {
#      18           "C": "30",
#      19           "image": null,
#      20           "is_correct": false
#      21         },
#      22         {
#      23           "D": "40",
#      24           "image": null,
#      25           "is_correct": false
#      26         }
#      27       ]
#      28     },
#      29     {
#      30       "question": "$A = a^{2} \\bullet b^{3} \\bullet c$ va $B = a \\bullet b^{2} \\bullet d$ sonlari uchun $EKUB(A;B)$ ning qiymatini toping",
#      31       "image": null,
#      32       "options": [
#      33         {
#      34           "A": "$ab$",
#      35           "image": null,
#      36           "is_correct": false
#      37         },
#      38         {
#      39           "B": "$a^{2}b$",
#      40           "image": null,
#      41           "is_correct": false
#      42         },
#      43         {
#      44           "C": "$ab^{2}$",
#      45           "image": null,
#      46           "is_correct": true
#      47         },
#      48         {
#      49           "D": "$a$",
#      50           "image": null,
#      51           "is_correct": false
#      52         }
#      53       ]
#      54     },
#      55     {
#      56       "question": "$EKUB(42;48)$",
#      57       "image": null,
#      58       "options": [
#      59         {
#      60           "A": "2",
#      61           "image": null,
#      62           "is_correct": false
#      63         },
#      64         {
#      65           "B": "3",
#      66           "image": null,
#      67           "is_correct": false
#      68         },
#      69         {
#      70           "C": "6",
#      71           "image": null,
#      72           "is_correct": true
#      73         },
#      74         {
#      75           "D": "8",
#      76           "image": null,
#      77           "is_correct": false
#      78         }
#      79       ]
#      80     },
#      81     {
#      82       "question": "$EKUB(24;36;48)$",
#      83       "image": null,
#      84       "options": [
#      85         {
#      86           "A": "6",
#      87           "image": null,
#      88           "is_correct": false
#      89         },
#      90         {
#      91           "B": "8",
#      92           "image": null,
#      93           "is_correct": false
#      94         },
#      95         {
#      96           "C": "9",
#      97           "image": null,
#      98           "is_correct": false
#      99         },
#     100         {
#     101           "D": "12",
#     102           "image": null,
#     103           "is_correct": true
#     104         }
#     105       ]
#     106     },
#     107     {
#     108       "question": "$A = a^{3} \\bullet b^{2} \\bullet c^{5}$ va $B = a^{2} \\bullet b^{4} \\bullet d^{3}$ sonlar uchun $EKUB(A;B)$ ning qiymatini toping",
#     109       "image": null,
#     110       "options": [
#     111         {
#     112           "A": "$ab$",
#     113           "image": null,
#     114           "is_correct": false
#     115         },
#     116         {
#     117           "B": "$a^{2}b$",
#     118           "image": null,
#     119           "is_correct": false
#     120         },
#     121         {
#     122           "C": "$a^{2}b^{2}$",
#     123           "image": null,
#     124           "is_correct": true
#     125         },
#     126         {
#     127           "D": "$a$",
#     128           "image": null,
#     129           "is_correct": false
#     130         }
#     131       ]
#     132     },
#     133     {
#     134       "question": "32 va 48 sonlarining EKUKibi toping",
#     135       "image": null,
#     136       "options": [
#     137         {
#     138           "A": "96",
#     139           "image": null,
#     140           "is_correct": false
#     141         },
#     142         {
#     143           "B": "100",
#     144           "image": null,
#     145           "is_correct": false
#     146         },
#     147         {
#     148           "C": "84",
#     149           "image": null,
#     150           "is_correct": false
#     151         },
#     152         {
#     153           "D": "96",
#     154           "image": null,
#     155           "is_correct": true
#     156         }
#     157       ]
#     158     },
#     159     {
#     160       "question": "$EKUK(15;24)$ ning qiymatini toping",
#     161       "image": null,
#     162       "options": [
#     163         {
#     164           "A": "60",
#     165           "image": null,
#     166           "is_correct": false
#     167         },
#     168         {
#     169           "B": "90",
#     170           "image": null,
#     171           "is_correct": false
#     172         },
#     173         {
#     174           "C": "120",
#     175           "image": null,
#     176           "is_correct": true
#     177         },
#     178         {
#     179           "D": "150",
#     180           "image": null,
#     181           "is_correct": false
#     182         }
#     183       ]
#     184     },
#     185     {
#     186       "question": "$EKUK(8;9;12)$ ning qiymatini toping",
#     187       "image": null,
#     188       "options": [
#     189         {
#     190           "A": "18",
#     191           "image": null,
#     192           "is_correct": false
#     193         },
#     194         {
#     195           "B": "24",
#     196           "image": null,
#     197           "is_correct": false
#     198         },
#     199         {
#     200           "C": "36",
#     201           "image": null,
#     202           "is_correct": false
#     203         },
#     204         {
#     205           "D": "72",
#     206           "image": null,
#     207           "is_correct": true
#     208         }
#     209       ]
#     210     },
#     211     {
#     212       "question": "$EKUB(A;B)=10$ bo'lib $A:B=3:5$ bo'lsa, $A+B$ ning qiymatini toping",
#     213       "image": null,
#     214       "options": [
#     215         {
#     216           "A": "50",
#     217           "image": null,
#     218           "is_correct": false
#     219         },
#     220         {
#     221           "B": "70",
#     222           "image": null,
#     223           "is_correct": false
#     224         },
#     225         {
#     226           "C": "80",
#     227           "image": null,
#     228           "is_correct": true
#     229         },
#     230         {
#     231           "D": "90",
#     232           "image": null,
#     233           "is_correct": false
#     234         }
#     235       ]
#     236     },
#     237     {
#     238       "question": "4800 ning tub bo'luvchilari sonini toping",
#     239       "image": null,
#     240       "options": [
#     241         {
#     242           "A": "42",
#     243           "image": null,
#     244           "is_correct": true
#     245         },
#     246         {
#     247           "B": "30",
#     248           "image": null,
#     249           "is_correct": false
#     250         },
#     251         {
#     252           "C": "15",
#     253           "image": null,
#     254           "is_correct": false
#     255         },
#     256         {
#     257           "D": "3",
#     258           "image": null,
#     259           "is_correct": false
#     260         }
#     261       ]
#     262     },
#     263     {
#     264       "question": "1440 ning tub bo'luvchilari yig'indisini toping",
#     265       "image": null,
#     266       "options": [
#     267         {
#     268           "A": "36",
#     269           "image": null,
#     270           "is_correct": false
#     271         },
#     272         {
#     273           "B": "30",
#     274           "image": null,
#     275           "is_correct": false
#     276         },
#     277         {
#     278           "C": "17",
#     279           "image": null,
#     280           "is_correct": false
#     281         },
#     282         {
#     283           "D": "10",
#     284           "image": null,
#     285           "is_correct": true
#     286         }
#     287       ]
#     288     },
#     289     {
#     290       "question": "$EKUB(72;60)+EKUK(28;20)$ ning qiymatini toping",
#     291       "image": null,
#     292       "options": [
#     293         {
#     294           "A": "119",
#     295           "image": null,
#     296           "is_correct": false
#     297         },
#     298         {
#     299           "B": "126",
#     300           "image": null,
#     301           "is_correct": false
#     302         },
#     303         {
#     304           "C": "136",
#     305           "image": null,
#     306           "is_correct": false
#     307         },
#     308         {
#     309           "D": "152",
#     310           "image": null,
#     311           "is_correct": true
#     312         }
#     313       ]
#     314     },
#     315     {
#     316       "question": "$A = 2^{3} \\bullet 3 \\bullet 5$ va $B = 2^{2} \\bullet 3^{2} \\bullet 7$ sonlari uchun $\\frac{EKUK(A;B)}{EKUB(A;B)}$ ning qiymatini toping",
#     317       "image": null,
#     318       "options": [
#     319         {
#     320           "A": "$210$",
#     321           "image": null,
#     322           "is_correct": true
#     323         },
#     324         {
#     325           "B": "$220$",
#     326           "image": null,
#     327           "is_correct": false
#     328         },
#     329         {
#     330           "C": "$240$",
#     331           "image": null,
#     332           "is_correct": false
#     333         },
#     334         {
#     335           "D": "$280$",
#     336           "image": null,
#     337           "is_correct": false
#     338         }
#     339       ]
#     340     },
#     341     {
#     342       "question": "$EKUB(12;140;36)+EKUK(6;16;20)$ ning qiymatini toping",
#     343       "image": null,
#     344       "options": [
#     345         {
#     346           "A": "198",
#     347           "image": null,
#     348           "is_correct": false
#     349         },
#     350         {
#     351           "B": "210",
#     352           "image": null,
#     353           "is_correct": false
#     354         },
#     355         {
#     356           "C": "244",
#     357           "image": null,
#     358           "is_correct": true
#     359         },
#     360         {
#     361           "D": "250",
#     362           "image": null,
#     363           "is_correct": false
#     364         }
#     365       ]
#     366     },
#     367     {
#     368       "question": "$EKUB(18;60;x)=6$ va $EKUK(18;60;x)=1260$ bo'lsa, $x$ ning eng kichik qiymatini toping",
#     369       "image": null,
#     370       "options": [
#     371         {
#     372           "A": "6",
#     373           "image": null,
#     374           "is_correct": false
#     375         },
#     376         {
#     377           "B": "18",
#     378           "image": null,
#     379           "is_correct": false
#     380         },
#     381         {
#     382           "C": "36",
#     383           "image": null,
#     384           "is_correct": false
#     385         },
#     386         {
#     387           "D": "42",
#     388           "image": null,
#     389           "is_correct": true
#     390         }
#     391       ]
#     392     },
#     393     {
#     394       "question": "$EKUB(24;x)=12$ va $EKUK(24;x)=120$ bo'lsa, $x$ ning raqamlari yig'indisini toping",
#     395       "image": null,
#     396       "options": [
#     397         {
#     398           "A": "4",
#     399           "image": null,
#     400           "is_correct": false
#     401         },
#     402         {
#     403           "B": "5",
#     404           "image": null,
#     405           "is_correct": true
#     406         },
#     407         {
#     408           "C": "6",
#     409           "image": null,
#     410           "is_correct": false
#     411         },
#     412         {
#     413           "D": "7",
#     414           "image": null,
#     415           "is_correct": false
#     416         }
#     417       ]
#     418     },
#     419     {
#     420       "question": "$EKUB(EKUK(72;20);EKUK(24;32))$ ning qiymatini toping",
#     421       "image": null,
#     422       "options": [
#     423         {
#     424           "A": "18",
#     425           "image": null,
#     426           "is_correct": false
#     427         },
#     428         {
#     429           "B": "24",
#     430           "image": null,
#     431           "is_correct": true
#     432         },
#     433         {
#     434           "C": "36",
#     435           "image": null,
#     436           "is_correct": false
#     437         },
#     438         {
#     439           "D": "72",
#     440           "image": null,
#     441           "is_correct": false
#     442         }
#     443       ]
#     444     },
#     445     {
#     446       "question": "$EKUB(x;12) \\cdot EKUK(x;12)=720$ bo'lsa, $EKUK(x;45)$ ning qiymatini toping",
#     447       "image": null,
#     448       "options": [
#     449         {
#     450           "A": "60",
#     451           "image": null,
#     452           "is_correct": false
#     453         },
#     454         {
#     455           "B": "90",
#     456           "image": null,
#     457           "is_correct": false
#     458         },
#     459         {
#     460           "C": "180",
#     461           "image": null,
#     462           "is_correct": true
#     463         },
#     464         {
#     465           "D": "240",
#     466           "image": null,
#     467           "is_correct": false
#     468         }
#     469       ]
#     470     },
#     471     {
#     472       "question": "$EKUB(72;25)+EKUK(14;35;30)$ ning qiymatini toping",
#     473       "image": null,
#     474       "options": [
#     475         {
#     476           "A": "121",
#     477           "image": null,
#     478           "is_correct": false
#     479         },
#     480         {
#     481           "B": "181",
#     482           "image": null,
#     483           "is_correct": false
#     484         },
#     485         {
#     486           "C": "205",
#     487           "image": null,
#     488           "is_correct": false
#     489         },
#     490         {
#     491           "D": "211",
#     492           "image": null,
#     493           "is_correct": true
#     494         }
#     495       ]
#     496     },
#     497     {
#     498       "question": "$EKUB(54;A)=18$ va $EKUK(54;A)=216$ bo'lsa, $A$ ning qiymatini toping",
#     499       "image": null,
#     500       "options": [
#     501         {
#     502           "A": "36",
#     503           "image": null,
#     504           "is_correct": false
#     505         },
#     506         {
#     507           "B": "48",
#     508           "image": null,
#     509           "is_correct": false
#     510         },
#     511         {
#     512           "C": "54",
#     513           "image": null,
#     514           "is_correct": false
#     515         },
#     516         {
#     517           "D": "72",
#     518           "image": null,
#     519           "is_correct": true
#     520         }
#     521       ]
#     522     },
#     523     {
#     524       "question": "O'zaro tub sonlarning EKUKi 60 ga teng bo'lib ulardan biri 5 ga teng bo'lsa, ikkinchi sonni toping",
#     525       "image": null,
#     526       "options": [
#     527         {
#     528           "A": "13",
#     529           "image": null,
#     530           "is_correct": false
#     531         },
#     532         {
#     533           "B": "12",
#     534           "image": null,
#     535           "is_correct": true
#     536         },
#     537         {
#     538           "C": "15",
#     539           "image": null,
#     540           "is_correct": false
#     541         },
#     542         {
#     543           "D": "20",
#     544           "image": null,
#     545           "is_correct": false
#     546         }
#     547       ]
#     548     },
#     549     {
#     550       "question": "$EKUK(36;A)=72$ va $EKUB(36;A)=12$ bo'lsa, $A$ ning qiymatini toping",
#     551       "image": null,
#     552       "options": [
#     553         {
#     554           "A": "14",
#     555           "image": null,
#     556           "is_correct": false
#     557         },
#     558         {
#     559           "B": "34",
#     560           "image": null,
#     561           "is_correct": false
#     562         },
#     563         {
#     564           "C": "24",
#     565           "image": null,
#     566           "is_correct": true
#     567         },
#     568         {
#     569           "D": "30",
#     570           "image": null,
#     571           "is_correct": false
#     572         }
#     573       ]
#     574     }
#     575   ]
#     576 }
#
# NameError: name 'null' is not defined

# %%
import json

questions = [
    {
        "question": "To'g'ri to'rtburchakning buyi 4 sm, eni bo'yidan 2,4 sm qisqa. To'g'ri to'rtburchakning yuzini toping.",
        "image": None,
        "options": [
            {"A": "6,4 sm²", "image": None, "is_correct": False},
            {"B": "4,8 sm²", "image": None, "is_correct": False},
            {"C": "5,4 sm²", "image": None, "is_correct": True},
            {"D": "7,2 sm²", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Amallarni bajaring. $(6 + 12) \\cdot 3$",
        "image": None,
        "options": [
            {"A": "42", "image": None, "is_correct": False},
            {"B": "30", "image": None, "is_correct": False},
            {"C": "54", "image": None, "is_correct": True},
            {"D": "48", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "$a = 2$, $v = 3$ bo'lganda $3a + 2v - 7$ algebraik ifodaning qiymatini toping.",
        "image": None,
        "options": [
            {"A": "5", "image": None, "is_correct": True},
            {"B": "10", "image": None, "is_correct": False},
            {"C": "-12", "image": None, "is_correct": False},
            {"D": "3", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "$2a + 3v$ bunda $a = 3$, $v = -2$ ifodaning qiymatini toping.",
        "image": None,
        "options": [
            {"A": "0", "image": None, "is_correct": True},
            {"B": "12", "image": None, "is_correct": False},
            {"C": "-12", "image": None, "is_correct": False},
            {"D": "6", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Qavslarni oching. $a + (2v + 3s)$",
        "image": None,
        "options": [
            {"A": "$a + 2v - 3s$", "image": None, "is_correct": False},
            {"B": "$a - 2v - 3s$", "image": None, "is_correct": False},
            {"C": "$a + 2v + 3s$", "image": None, "is_correct": True},
            {"D": "$a - 2v + 3s$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Soddalashtiring $(5a - 2v) - (3v - 5a)$",
        "image": None,
        "options": [
            {"A": "$8av - 7va$", "image": None, "is_correct": False},
            {"B": "$10a - 5v$", "image": None, "is_correct": True},
            {"C": "$10a + 6v$", "image": None, "is_correct": False},
            {"D": "$5a - 3v$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Ifodaning son qiymatini toping. $p = 2(a + v)$, $a = 5$, $v = 7$",
        "image": None,
        "options": [
            {"A": "24", "image": None, "is_correct": True},
            {"B": "4", "image": None, "is_correct": False},
            {"C": "8", "image": None, "is_correct": False},
            {"D": "16", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Tenglamani yeching. $x = 3$",
        "image": None,
        "options": [
            {"A": "1,5", "image": None, "is_correct": False},
            {"B": "6", "image": None, "is_correct": True},
            {"C": "8", "image": None, "is_correct": False},
            {"D": "4", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Tenglamani yeching $25x - 1 = 9$",
        "image": None,
        "options": [
            {"A": "0,4", "image": None, "is_correct": True},
            {"B": "32", "image": None, "is_correct": False},
            {"C": "34", "image": None, "is_correct": False},
            {"D": "0,5", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Qavslarni oching $a + (2v - 3s)$",
        "image": None,
        "options": [
            {"A": "$a + 2v + 3s$", "image": None, "is_correct": False},
            {"B": "$a + 2v - 3s$", "image": None, "is_correct": True},
            {"C": "$a - 2v - 3s$", "image": None, "is_correct": False},
            {"D": "$a - 2v + 3s$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "To'g'ri to'rtburchakning bo'yi 8 sm ga teng. Eni bo'yidan 1,5 sm qisqa. To'g'ri to'rtburchakning yuzini toping.",
        "image": None,
        "options": [
            {"A": "50 sm²", "image": None, "is_correct": False},
            {"B": "60 sm²", "image": None, "is_correct": False},
            {"C": "52 sm²", "image": None, "is_correct": True},
            {"D": "55 sm²", "image": None, "is_correct": False}
        ]
    }
]

print(json.dumps(questions, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "question": "To'g'ri to'rtburchakning buyi 4 sm, eni bo'yidan 2,4 sm qisqa. To'g'ri to'rtburchakning yuzini toping.",
#     "image": null,
#     "options": [
#       {
#         "A": "6,4 sm²",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "4,8 sm²",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "5,4 sm²",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "7,2 sm²",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Amallarni bajaring. $(6 + 12) \\cdot 3$",
#     "image": null,
#     "options": [
#       {
#         "A": "42",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "30",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "54",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "48",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "$a = 2$, $v = 3$ bo'lganda $3a + 2v - 7$ algebraik ifodaning qiymatini toping.",
#     "image": null,
#     "options": [
#       {
#         "A": "5",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "10",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "-12",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "3",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "$2a + 3v$ bunda $a = 3$, $v = -2$ ifodaning qiymatini toping.",
#     "image": null,
#     "options": [
#       {
#         "A": "0",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "12",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "-12",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "6",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Qavslarni oching. $a + (2v + 3s)$",
#     "image": null,
#     "options": [
#       {
#         "A": "$a + 2v - 3s$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "$a - 2v - 3s$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "$a + 2v + 3s$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "$a - 2v + 3s$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Soddalashtiring $(5a - 2v) - (3v - 5a)$",
#     "image": null,
#     "options": [
#       {
#         "A": "$8av - 7va$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "$10a - 5v$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "$10a + 6v$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "$5a - 3v$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Ifodaning son qiymatini toping. $p = 2(a + v)$, $a = 5$, $v = 7$",
#     "image": null,
#     "options": [
#       {
#         "A": "24",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "4",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "8",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "16",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Tenglamani yeching. $x = 3$",
#     "image": null,
#     "options": [
#       {
#         "A": "1,5",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "6",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "8",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "4",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Tenglamani yeching $25x - 1 = 9$",
#     "image": null,
#     "options": [
#       {
#         "A": "0,4",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "32",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "34",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "0,5",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Qavslarni oching $a + (2v - 3s)$",
#     "image": null,
#     "options": [
#       {
#         "A": "$a + 2v + 3s$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "$a + 2v - 3s$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "$a - 2v - 3s$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "$a - 2v + 3s$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "To'g'ri to'rtburchakning bo'yi 8 sm ga teng. Eni bo'yidan 1,5 sm qisqa. To'g'ri to'rtburchakning yuzini toping.",
#     "image": null,
#     "options": [
#       {
#         "A": "50 sm²",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "60 sm²",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "52 sm²",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "55 sm²",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   }
# ]

# %%
import json

questions = [
    {
        "question": "Umumiy ko'paytuvchini qavsdan chiqarish amali qaysi javobda to'g'ri ko'rsatilgan? $3a - 3x$",
        "image": None,
        "options": [
            {"A": "$(3a - 3x)$", "image": None, "is_correct": False},
            {"B": "$3ax$", "image": None, "is_correct": False},
            {"C": "$3(a - x)$", "image": None, "is_correct": True},
            {"D": "$3a - x$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "85 sm.ni diametrda ifodalang.",
        "image": None,
        "options": [
            {"A": "85 dm.", "image": None, "is_correct": False},
            {"B": "8,5 dm.", "image": None, "is_correct": True},
            {"C": "0,85 dm.", "image": None, "is_correct": False},
            {"D": "10,5 dm.", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Eng soda geometric shakl nima?",
        "image": None,
        "options": [
            {"A": "nuqta", "image": None, "is_correct": True},
            {"B": "vergul", "image": None, "is_correct": False},
            {"C": "to'g'ri chiziq", "image": None, "is_correct": False},
            {"D": "aylana", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Ikkita nuqta orqali nechta to'g'ri chiziq o'tkazish mumkin?",
        "image": None,
        "options": [
            {"A": "3 ta", "image": None, "is_correct": False},
            {"B": "2 ta", "image": None, "is_correct": False},
            {"C": "1 ta", "image": None, "is_correct": True},
            {"D": "4 ta", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Birhadni boshqa birhadning kvadrati shaklida yozing: $9a^2$",
        "image": None,
        "options": [
            {"A": "$3^2a^2$", "image": None, "is_correct": True},
            {"B": "$3^3a^2$", "image": None, "is_correct": False},
            {"C": "$3^4a^2$", "image": None, "is_correct": False},
            {"D": "$3a^2$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Birhadni darajaga ko'paytiring: $(2a)^3$",
        "image": None,
        "options": [
            {"A": "$2a^4$", "image": None, "is_correct": False},
            {"B": "$2^3a^3$", "image": None, "is_correct": True},
            {"C": "$2a^5$", "image": None, "is_correct": False},
            {"D": "$8a^3$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Birhadni boshqa birhadning kubi shaklida yozing: $27a^3$",
        "image": None,
        "options": [
            {"A": "$27^3a^3$", "image": None, "is_correct": False},
            {"B": "$9^3a^3$", "image": None, "is_correct": False},
            {"C": "$3^3a^3$", "image": None, "is_correct": True},
            {"D": "$3^2a^3$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Birhadni ko'paytiring: $(2a)(3b)$",
        "image": None,
        "options": [
            {"A": "$6ab$", "image": None, "is_correct": True},
            {"B": "$5ba$", "image": None, "is_correct": False},
            {"C": "$2^3ab$", "image": None, "is_correct": False},
            {"D": "$5ab$", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Ko'phadlar deb nimaga aytiladi?",
        "image": None,
        "options": [
            {"A": "Bir necha birhadning algebraik yig'indisi ko'phad deyiladi", "image": None, "is_correct": False},
            {"B": "Bir necha birhadlar ko'paytmasi ko'phad deyiladi", "image": None, "is_correct": True},
            {"C": "Bir necha ko'phadlarning algebraik yig'indisi ko'phad deyiladi", "image": None, "is_correct": False},
            {"D": "Bir necha algebraik ifodalarning ko'paytmasi ko'phad deyiladi", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "$2a^3 + 3ab$ bunda $a = 1$, $b = 2$ ko'phadni son qiymati qaysi javobda to'g'ri ko'rsatilgan?",
        "image": None,
        "options": [
            {"A": "6", "image": None, "is_correct": False},
            {"B": "8", "image": None, "is_correct": True},
            {"C": "10", "image": None, "is_correct": False},
            {"D": "7", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Har qanday ko'phadni qanday standart shakga keltirish mumkin?",
        "image": None,
        "options": [
            {"A": "Avval har bir hadini standart shaklda yozish, so'ngra o'xshash hadlarini ixchamlash kerak", "image": None, "is_correct": True},
            {"B": "Oldin o'xshash hadlarini ixchamlanadi", "image": None, "is_correct": False},
            {"C": "Javoblar noto'g'ri", "image": None, "is_correct": False},
            {"D": "Har bir hadni alohida qarab o'tish kerak", "image": None, "is_correct": False}
        ]
    },
    {
        "question": "Poezdning uzunligi 800 m. U ustun yonidan 40 sekundda o'tib ketdi. Poezdning tezligini toping.",
        "image": None,
        "options": [
            {"A": "30 m/s", "image": None, "is_correct": False},
            {"B": "15 m/s", "image": None, "is_correct": False},
            {"C": "20 m/s", "image": None, "is_correct": True},
            {"D": "25 m/s", "image": None, "is_correct": False}
        ]
    }
]

print(json.dumps(questions, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "question": "Umumiy ko'paytuvchini qavsdan chiqarish amali qaysi javobda to'g'ri ko'rsatilgan? $3a - 3x$",
#     "image": null,
#     "options": [
#       {
#         "A": "$(3a - 3x)$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "$3ax$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "$3(a - x)$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "$3a - x$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "85 sm.ni diametrda ifodalang.",
#     "image": null,
#     "options": [
#       {
#         "A": "85 dm.",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "8,5 dm.",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "0,85 dm.",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "10,5 dm.",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Eng soda geometric shakl nima?",
#     "image": null,
#     "options": [
#       {
#         "A": "nuqta",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "vergul",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "to'g'ri chiziq",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "aylana",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Ikkita nuqta orqali nechta to'g'ri chiziq o'tkazish mumkin?",
#     "image": null,
#     "options": [
#       {
#         "A": "3 ta",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "2 ta",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "1 ta",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "4 ta",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Birhadni boshqa birhadning kvadrati shaklida yozing: $9a^2$",
#     "image": null,
#     "options": [
#       {
#         "A": "$3^2a^2$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "$3^3a^2$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "$3^4a^2$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "$3a^2$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Birhadni darajaga ko'paytiring: $(2a)^3$",
#     "image": null,
#     "options": [
#       {
#         "A": "$2a^4$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "$2^3a^3$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "$2a^5$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "$8a^3$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Birhadni boshqa birhadning kubi shaklida yozing: $27a^3$",
#     "image": null,
#     "options": [
#       {
#         "A": "$27^3a^3$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "$9^3a^3$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "$3^3a^3$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "$3^2a^3$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Birhadni ko'paytiring: $(2a)(3b)$",
#     "image": null,
#     "options": [
#       {
#         "A": "$6ab$",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "$5ba$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "$2^3ab$",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "$5ab$",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Ko'phadlar deb nimaga aytiladi?",
#     "image": null,
#     "options": [
#       {
#         "A": "Bir necha birhadning algebraik yig'indisi ko'phad deyiladi",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "Bir necha birhadlar ko'paytmasi ko'phad deyiladi",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "Bir necha ko'phadlarning algebraik yig'indisi ko'phad deyiladi",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "Bir necha algebraik ifodalarning ko'paytmasi ko'phad deyiladi",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "$2a^3 + 3ab$ bunda $a = 1$, $b = 2$ ko'phadni son qiymati qaysi javobda to'g'ri ko'rsatilgan?",
#     "image": null,
#     "options": [
#       {
#         "A": "6",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "8",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "C": "10",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "7",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Har qanday ko'phadni qanday standart shakga keltirish mumkin?",
#     "image": null,
#     "options": [
#       {
#         "A": "Avval har bir hadini standart shaklda yozish, so'ngra o'xshash hadlarini ixchamlash kerak",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "B": "Oldin o'xshash hadlarini ixchamlanadi",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "Javoblar noto'g'ri",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "D": "Har bir hadni alohida qarab o'tish kerak",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   },
#   {
#     "question": "Poezdning uzunligi 800 m. U ustun yonidan 40 sekundda o'tib ketdi. Poezdning tezligini toping.",
#     "image": null,
#     "options": [
#       {
#         "A": "30 m/s",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "B": "15 m/s",
#         "image": null,
#         "is_correct": false
#       },
#       {
#         "C": "20 m/s",
#         "image": null,
#         "is_correct": true
#       },
#       {
#         "D": "25 m/s",
#         "image": null,
#         "is_correct": false
#       }
#     ]
#   }
# ]
